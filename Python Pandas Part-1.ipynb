# %%
import pandas as pd

# %%
df = pd.read_csv(r'https://raw.githubusercontent.com/attaurrahman294/Datasets/main/SampleSuperstore.csv')
df.head(1)
# Out:
#       Ship Mode   Segment        Country       City     State  Postal Code  \
# 0  Second Class  Consumer  United States  Henderson  Kentucky        42420
#
#   Region   Category Sub-Category   Sales  Quantity  Discount   Profit
# 0  South  Furniture    Bookcases  261.96         2       0.0  41.9136

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
# read specific rwod from data fram
df = pd.read_csv(r'https://raw.githubusercontent.com/attaurrahman294/Datasets/main/SampleSuperstore.csv' , nrows=3)
df
# Out:
#       Ship Mode    Segment        Country         City       State  \
# 0  Second Class   Consumer  United States    Henderson    Kentucky
# 1  Second Class   Consumer  United States    Henderson    Kentucky
# 2  Second Class  Corporate  United States  Los Angeles  California
#
#    Postal Code Region         Category Sub-Category   Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.96         2
# 1        42420  South        Furniture       Chairs  731.94         3
# 2        90036   West  Office Supplies       Labels   14.62         2
#
#    Discount    Profit
# 0         0   41.9136
# 1         0  219.5820
# 2         0    6.8714

# %%
df.iloc[0:3,:]
# Out:
#       Ship Mode    Segment        Country         City       State  \
# 0  Second Class   Consumer  United States    Henderson    Kentucky
# 1  Second Class   Consumer  United States    Henderson    Kentucky
# 2  Second Class  Corporate  United States  Los Angeles  California
#
#    Postal Code Region         Category Sub-Category   Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.96         2
# 1        42420  South        Furniture       Chairs  731.94         3
# 2        90036   West  Office Supplies       Labels   14.62         2
#
#    Discount    Profit
# 0         0   41.9136
# 1         0  219.5820
# 2         0    6.8714

# %%
df = pd.read_csv(r'E:\BI\PowerBi\Power BI Tutorial\super store data anlysis\SampleSuperstore.csv')
df.head(11)
# Out:
#          Ship Mode    Segment        Country             City       State  \
# 0     Second Class   Consumer  United States        Henderson    Kentucky
# 1     Second Class   Consumer  United States        Henderson    Kentucky
# 2     Second Class  Corporate  United States      Los Angeles  California
# 3   Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4   Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5   Standard Class   Consumer  United States      Los Angeles  California
# 6   Standard Class   Consumer  United States      Los Angeles  California
# 7   Standard Class   Consumer  United States      Los Angeles  California
# 8   Standard Class   Consumer  United States      Los Angeles  California
# 9   Standard Class   Consumer  United States      Los Angeles  California
# 10  Standard Class   Consumer  United States      Los Angeles  California
#
#     Postal Code Region         Category Sub-Category      Sales  Quantity  \
# ...

# %%
df.loc[10:20, ['Sales','Profit']].head(1)
# Out:
#        Sales   Profit
# 10  1706.184  85.3092

# %%
# To read a specific column from the dataframe
df = pd.read_csv(r'https://raw.githubusercontent.com/attaurrahman294/Datasets/main/SampleSuperstore.csv', usecols=[0])
df.head(1)
# Out:
#       Ship Mode
# 0  Second Class

# %%
# To read a specific column from the dataframe
df = pd.read_csv(r'https://raw.githubusercontent.com/attaurrahman294/Datasets/main/SampleSuperstore.csv', usecols=[0 , 1 , 2])
df.head(1)
# Out:
#       Ship Mode   Segment        Country
# 0  Second Class  Consumer  United States

# %%
# To read a specific column from the dataframe
df = pd.read_csv(r'https://raw.githubusercontent.com/attaurrahman294/Datasets/main/SampleSuperstore.csv')
df.head(1)
# Out:
#       Ship Mode   Segment        Country       City     State  Postal Code  \
# 0  Second Class  Consumer  United States  Henderson  Kentucky        42420
#
#   Region   Category Sub-Category   Sales  Quantity  Discount   Profit
# 0  South  Furniture    Bookcases  261.96         2       0.0  41.9136

# %%
# to proint very iportant and specific column from datafram
df = pd.read_csv(r'https://raw.githubusercontent.com/attaurrahman294/Datasets/main/SampleSuperstore.csv', usecols=[2,6,9,10,12])
df.head(1)
# Out:
#          Country Region   Sales  Quantity   Profit
# 0  United States  South  261.96         2  41.9136

# %%
# Use first row as header like powerbi 
df = pd.read_csv(r'https://raw.githubusercontent.com/attaurrahman294/Datasets/main/SampleSuperstore.csv', skiprows=[0])
df.head(1)
# Out:
#    Second Class  Consumer  United States  Henderson  Kentucky  42420  South  \
# 0  Second Class  Consumer  United States  Henderson  Kentucky  42420  South
#
#    Furniture Bookcases  261.96  2    0  41.9136
# 0  Furniture    Chairs  731.94  3  0.0  219.582

# %%
# Use first row as header like powerbi 
# this is the normal data set we have skip first row of the same data set in the above cell
df = pd.read_csv(r'https://raw.githubusercontent.com/attaurrahman294/Datasets/main/SampleSuperstore.csv')
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# To skip any two rows from the data fram
# Use first row as header like powerbi 
df = pd.read_csv(r'https://raw.githubusercontent.com/attaurrahman294/Datasets/main/SampleSuperstore.csv', skiprows=[2,3])
df.head()
# Out:
#         Ship Mode   Segment        Country             City       State  \
# 0    Second Class  Consumer  United States        Henderson    Kentucky
# 1  Standard Class  Consumer  United States  Fort Lauderdale     Florida
# 2  Standard Class  Consumer  United States  Fort Lauderdale     Florida
# 3  Standard Class  Consumer  United States      Los Angeles  California
# 4  Standard Class  Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        33311  South        Furniture       Tables  957.5775         5
# 2        33311  South  Office Supplies      Storage   22.3680         2
# 3        90032   West        Furniture  Furnishings   48.8600         7
# 4        90032   West  Office Supplies          Art    7.2800         4
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.45 -383.0310
# 2      0.20    2.5164
# ...

# %%
# To Use any column as index
df = pd.read_csv(r'https://raw.githubusercontent.com/attaurrahman294/Datasets/main/SampleSuperstore.csv' , index_col= 'Category')
df['new'] = range(1,9995)
df
# Out:
#                       Ship Mode    Segment        Country             City  \
# Category
# Furniture          Second Class   Consumer  United States        Henderson
# Furniture          Second Class   Consumer  United States        Henderson
# Office Supplies    Second Class  Corporate  United States      Los Angeles
# Furniture        Standard Class   Consumer  United States  Fort Lauderdale
# Office Supplies  Standard Class   Consumer  United States  Fort Lauderdale
# ...                         ...        ...            ...              ...
# Furniture          Second Class   Consumer  United States            Miami
# Furniture        Standard Class   Consumer  United States       Costa Mesa
# Technology       Standard Class   Consumer  United States       Costa Mesa
# Office Supplies  Standard Class   Consumer  United States       Costa Mesa
# Office Supplies    Second Class   Consumer  United States      Westminster
#
# ...

# %%
# To Use any column as index
df = pd.read_csv(r'https://raw.githubusercontent.com/attaurrahman294/Datasets/main/SampleSuperstore.csv')
df['new'] = range(1,9995)
pd.DataFrame(df , index= df['new'])
# Out:
#            Ship Mode    Segment        Country             City       State  \
# new
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5     Standard Class   Consumer  United States      Los Angeles  California
# ...              ...        ...            ...              ...         ...
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
# 9994             NaN        NaN            NaN              NaN         NaN
#
# ...

# %% [markdown]
# # How to write csv file

# %%
# the below actula dat is this 
df = pd.read_csv(r'https://raw.githubusercontent.com/attaurrahman294/Datasets/main/SampleSuperstore.csv')
df.head(1)
# Out:
#       Ship Mode   Segment        Country       City     State  Postal Code  \
# 0  Second Class  Consumer  United States  Henderson  Kentucky        42420
#
#   Region   Category Sub-Category   Sales  Quantity  Discount   Profit
# 0  South  Furniture    Bookcases  261.96         2       0.0  41.9136

# %%
# To Use any column as index
# 
df = pd.read_csv(r'https://raw.githubusercontent.com/attaurrahman294/Datasets/main/SampleSuperstore.csv', header=None ,)
df.head()
# Out:
#                0          1              2                3           4   \
# 0       Ship Mode    Segment        Country             City       State
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class   Consumer  United States        Henderson    Kentucky
# 3    Second Class  Corporate  United States      Los Angeles  California
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#             5       6                7             8         9         10  \
# 0  Postal Code  Region         Category  Sub-Category     Sales  Quantity
# 1        42420   South        Furniture     Bookcases    261.96         2
# 2        42420   South        Furniture        Chairs    731.94         3
# 3        90036    West  Office Supplies        Labels     14.62         2
# 4        33311   South        Furniture        Tables  957.5775         5
#
#          11        12
# 0  Discount    Profit
# 1         0   41.9136
# ...

# %%
# to add  prefix to the columns
import pandas as pd 
df = pd.read_csv(r'E:\BI\PowerBi\Power BI Tutorial\super store data anlysis\SampleSuperstore.csv', header=None , prefix='Col')
df.head()
# Out:
# C:\Users\Attaur Rahman\AppData\Local\Temp\ipykernel_7636\928091951.py:3: FutureWarning: The prefix argument has been deprecated and will be removed in a future version. Use a list comprehension on the column names in the future.
#
#
#   df = pd.read_csv(r'E:\BI\PowerBi\Power BI Tutorial\super store data anlysis\SampleSuperstore.csv', header=None , prefix='Col')
#              Col0       Col1           Col2             Col3        Col4  \
# 0       Ship Mode    Segment        Country             City       State
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class   Consumer  United States        Henderson    Kentucky
# 3    Second Class  Corporate  United States      Los Angeles  California
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#           Col5    Col6             Col7          Col8      Col9     Col10  \
# 0  Postal Code  Region         Category  Sub-Category     Sales  Quantity
# ...

# %%
# to add  prefix to the columns
df = pd.read_csv(r'E:\BI\PowerBi\Power BI Tutorial\super store data anlysis\SampleSuperstore.csv', names=['a' ,'b' ,'c','ff' ,'g' ,'h','i' ,'j' ,'k','l' ,'m' ,'n'])
df.head()
# Out:
#                         a              b                c          ff  \
# Ship Mode         Segment        Country             City       State
# Second Class     Consumer  United States        Henderson    Kentucky
# Second Class     Consumer  United States        Henderson    Kentucky
# Second Class    Corporate  United States      Los Angeles  California
# Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#                           g       h                i             j         k  \
# Ship Mode       Postal Code  Region         Category  Sub-Category     Sales
# Second Class          42420   South        Furniture     Bookcases    261.96
# Second Class          42420   South        Furniture        Chairs    731.94
# Second Class          90036    West  Office Supplies        Labels     14.62
# Standard Class        33311   South        Furniture        Tables  957.5775
#
#                        l         m         n
# ...

# %%
# write a csv
df = pd.read_csv(r'E:\BI\PowerBi\Power BI Tutorial\super store data anlysis\SampleSuperstore.csv' , true_values=['South'] , false_values=['West'])
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# add new column with the help of existing column
df['new'] = df.loc[df['Region'] == 'South' , 'Region'] = 'True'
#df.loc[df['Region'] == 'West' , 'Region'] = 'True'
df['new'] = df['Quantity']*df['Sales']
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df['Sales'].dtype
# Out:
# dtype('float64')

# %%
# write a csv
# Change dtype of any columns
df = pd.read_csv(r'E:\BI\PowerBi\Power BI Tutorial\super store data anlysis\SampleSuperstore.csv', dtype={'Quantity' : 'float64'})
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600       2.0
# 1        42420  South        Furniture       Chairs  731.9400       3.0
# 2        90036   West  Office Supplies       Labels   14.6200       2.0
# 3        33311  South        Furniture       Tables  957.5775       5.0
# 4        33311  South  Office Supplies      Storage   22.3680       2.0
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df['new'] = df['Sales']*df['Quantity']
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...
